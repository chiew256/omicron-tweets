# %%
# Load packages

import pandas as pd
import networkx as nx

# %%
df = pd.read_csv('omicron.csv')

# %%
df.tail()
# Out:
#                         id                              user_name
# 17041  1499644571827019777                   Self Clean Solutions  \
# 17042  1499644487705849856                           Kuldip Patel
# 17043  1499643983877873666  Dr Asad Khan FRCP FRACP 🇵🇸🇳🇿🇮🇳🇬🇧#FBLC
# 17044  1499643896174989316    Dr. Melvin Sanicas | #GetVaccinated
# 17045  1499643806697750533                     Yellow Cab of D.C.
#
#                       user_location
# 17041      Scotland, United Kingdom  \
# 17042  Auckland Region, New Zealand
# 17043                 Plague Island
# 17044       Switzerland & Singapore
# 17045               Washington D.C.
#
#                                         user_description         user_created
# 17041  PureZone are making clean, visible. We special...  2019-03-27 15:05:56  \
# 17042                           Love Sports, Live Sports  2011-02-07 10:32:23
# 17043  Lung doctor. Life on pause since Nov 20 #LongC...  2014-07-30 10:38:00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17046 entries, 0 to 17045
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                17046 non-null  int64
#  1   user_name         17046 non-null  object
#  2   user_location     13433 non-null  object
#  3   user_description  15716 non-null  object
#  4   user_created      17046 non-null  object
#  5   user_followers    17046 non-null  int64
#  6   user_friends      17046 non-null  int64
#  7   user_favourites   17046 non-null  int64
#  8   user_verified     17046 non-null  bool
#  9   date              17046 non-null  object
#  10  text              17046 non-null  object
#  11  hashtags          10219 non-null  object
#  12  source            17046 non-null  object
#  13  retweets          17046 non-null  int64
#  14  favorites         17046 non-null  int64
#  15  is_retweet        17046 non-null  bool
# ...

# %%
us_graph = nx.from_pandas_edgelist(df,source="source", target="retweets")

# %%
type(us_graph)
# Out:
# networkx.classes.graph.Graph

# %%
nx.info(us_graph)
# Out:
# 'Name: \nType: Graph\nNumber of nodes: 295\nNumber of edges: 576\nAverage degree:   3.9051'

# %%
us_graph.nodes()
# Out:
# NodeView(('smcapplication', 0, 'Twitter Web App', 2, 'Agorapulse app', 'Twitter for iPhone', 1, 'Twitter for Android', 'Paper.li', 'Hootsuite Inc.', 'LaterMedia', 'Buffer', 'WordPress.com', 'Sprinklr', 'Echobox', 'Sprout Social', 3, 'Twitter for iPad', 'TweetDeck', 'The Social Jukebox', 4, 'Twitter for Mac', 98, 5, 'HubSpot', 8, 'Instagram', 'HeyOrca', 12, 'Salesforce - Social Studio', 6, 13, 72, 'Twitter for Advertisers.', 18, 'Intelligent Transport', 27, 7, 9, 19, 'News Medical', 567, 16, 'IFTTT', 'dlvr.it', 'Tweetbot for iΟS', 51, 23, 'AIT News', 'Science X Status Updates', 17, 'La Vie Zine', 'LinkedIn', 'nertiqatja', 'Twitter Media Studio - LiveCut', 'Microsoft Power Platform', 'IndiaPost', 'Zoho Social', 24, 10, 'Talon Android', 'ETRetail.com', 'National Herald', 15, 'Canva', 'GETTR-Sync-Production', 'Ohhtweet', 'Grabyo', 'Emplifi', 14, 11, 32, 'Periscope', 25, 'Blog2Social APP', 'Twitter Media Studio', 'SmarterQueue', 'Raven Tools', 'GoDaddy Social App', 'Crowdfire App', 'AutoL
# ...

# %%
len(us_graph.nodes())
# Out:
# 295

# %%
us_graph.edges()
# Out:
# EdgeView([('smcapplication', 0), ('smcapplication', 2), ('smcapplication', 1), ('smcapplication', 3), ('smcapplication', 4), (0, 'Twitter Web App'), (0, 'Agorapulse app'), (0, 'Twitter for iPhone'), (0, 'Twitter for Android'), (0, 'Paper.li'), (0, 'Hootsuite Inc.'), (0, 'LaterMedia'), (0, 'Buffer'), (0, 'WordPress.com'), (0, 'Echobox'), (0, 'Sprout Social'), (0, 'Twitter for iPad'), (0, 'TweetDeck'), (0, 'Instagram'), (0, 'HubSpot'), (0, 'The Social Jukebox'), (0, 'Twitter for Advertisers.'), (0, 'IFTTT'), (0, 'Tweetbot for iΟS'), (0, 'AIT News'), (0, 'Science X Status Updates'), (0, 'News Medical'), (0, 'LinkedIn'), (0, 'nertiqatja'), (0, 'Microsoft Power Platform'), (0, 'IndiaPost'), (0, 'Zoho Social'), (0, 'Talon Android'), (0, 'ETRetail.com'), (0, 'dlvr.it'), (0, 'Canva'), (0, 'GETTR-Sync-Production'), (0, 'Ohhtweet'), (0, 'Emplifi'), (0, 'Blog2Social APP'), (0, 'Raven Tools'), (0, 'GoDaddy Social App'), (0, 'Crowdfire App'), (0, 'AutoLuisAlejoVega'), (0, 'Zapier.com'), (0, 'News
# ...

# %%
len(us_graph.edges())
# Out:
# 576

# %%
us_graph.nodes()
# Out:
# NodeView(('smcapplication', 0, 'Twitter Web App', 2, 'Agorapulse app', 'Twitter for iPhone', 1, 'Twitter for Android', 'Paper.li', 'Hootsuite Inc.', 'LaterMedia', 'Buffer', 'WordPress.com', 'Sprinklr', 'Echobox', 'Sprout Social', 3, 'Twitter for iPad', 'TweetDeck', 'The Social Jukebox', 4, 'Twitter for Mac', 98, 5, 'HubSpot', 8, 'Instagram', 'HeyOrca', 12, 'Salesforce - Social Studio', 6, 13, 72, 'Twitter for Advertisers.', 18, 'Intelligent Transport', 27, 7, 9, 19, 'News Medical', 567, 16, 'IFTTT', 'dlvr.it', 'Tweetbot for iΟS', 51, 23, 'AIT News', 'Science X Status Updates', 17, 'La Vie Zine', 'LinkedIn', 'nertiqatja', 'Twitter Media Studio - LiveCut', 'Microsoft Power Platform', 'IndiaPost', 'Zoho Social', 24, 10, 'Talon Android', 'ETRetail.com', 'National Herald', 15, 'Canva', 'GETTR-Sync-Production', 'Ohhtweet', 'Grabyo', 'Emplifi', 14, 11, 32, 'Periscope', 25, 'Blog2Social APP', 'Twitter Media Studio', 'SmarterQueue', 'Raven Tools', 'GoDaddy Social App', 'Crowdfire App', 'AutoL
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(20,20))
nx.draw_networkx(us_graph, node_color='#FF8C00', edge_color='#1E90FF');

# %%
nx.draw_networkx(us_graph, node_color='#FF8C00', edge_color='#1E90FF')

# %%
print(nx.info(us_graph))
# Out:
# Name:
# Type: Graph
# Number of nodes: 295
# Number of edges: 576
# Average degree:   3.9051

# %%
plt.savefig("vacc.png")

# %% [markdown]
# # Analysis
# + Degree of Centrality
# - Most Influential
# - Most important connection
# - Best betweener
# - Shortest Path

# %%
# General Connection

nx.degree(us_graph)
# Out:
# DegreeView({'smcapplication': 5, 0: 134, 'Twitter Web App': 89, 2: 39, 'Agorapulse app': 1, 'Twitter for iPhone': 55, 1: 73, 'Twitter for Android': 38, 'Paper.li': 2, 'Hootsuite Inc.': 14, 'LaterMedia': 4, 'Buffer': 11, 'WordPress.com': 3, 'Sprinklr': 8, 'Echobox': 9, 'Sprout Social': 9, 3: 26, 'Twitter for iPad': 20, 'TweetDeck': 20, 'The Social Jukebox': 7, 4: 19, 'Twitter for Mac': 19, 98: 2, 5: 16, 'HubSpot': 4, 8: 11, 'Instagram': 1, 'HeyOrca': 2, 12: 9, 'Salesforce - Social Studio': 5, 6: 15, 13: 8, 72: 2, 'Twitter for Advertisers.': 2, 18: 5, 'Intelligent Transport': 1, 27: 2, 7: 14, 9: 12, 19: 4, 'News Medical': 5, 567: 1, 16: 5, 'IFTTT': 2, 'dlvr.it': 6, 'Tweetbot for iΟS': 2, 51: 2, 23: 3, 'AIT News': 2, 'Science X Status Updates': 2, 17: 4, 'La Vie Zine': 1, 'LinkedIn': 4, 'nertiqatja': 1, 'Twitter Media Studio - LiveCut': 2, 'Microsoft Power Platform': 1, 'IndiaPost': 1, 'Zoho Social': 4, 24: 2, 10: 9, 'Talon Android': 1, 'ETRetail.com': 1, 'National Herald': 4, 15: 5, 'C
# ...

# %%
# Degree of Connection

nx.degree(us_graph,"Twitter for Android")
# Out:
# 38

# %% [markdown]
# # MOST INFLUENTION
#
# - nx.degree_centrality

# %%
nx.degree_centrality(us_graph)
# Out:
# {'smcapplication': 0.017006802721088433,
#  0: 0.4557823129251701,
#  'Twitter Web App': 0.30272108843537415,
#  2: 0.1326530612244898,
#  'Agorapulse app': 0.003401360544217687,
#  'Twitter for iPhone': 0.18707482993197277,
#  1: 0.24829931972789115,
#  'Twitter for Android': 0.1292517006802721,
#  'Paper.li': 0.006802721088435374,
#  'Hootsuite Inc.': 0.047619047619047616,
#  'LaterMedia': 0.013605442176870748,
#  'Buffer': 0.03741496598639456,
#  'WordPress.com': 0.01020408163265306,
#  'Sprinklr': 0.027210884353741496,
#  'Echobox': 0.030612244897959183,
#  'Sprout Social': 0.030612244897959183,
#  3: 0.08843537414965986,
#  'Twitter for iPad': 0.06802721088435373,
#  'TweetDeck': 0.06802721088435373,
#  'The Social Jukebox': 0.023809523809523808,
#  4: 0.06462585034013606,
#  'Twitter for Mac': 0.06462585034013606,
#  98: 0.006802721088435374,
#  5: 0.05442176870748299,
#  'HubSpot': 0.013605442176870748,
#  8: 0.03741496598639456,
#  'Instagram': 0.003401360544217687,
# ...

# %%
sorted(nx.degree_centrality(us_graph).values())
# Out:
# [0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
#  0.003401360544217687,
# ...

# %%
most_influential = nx.degree_centrality(us_graph)

# %%
for w in sorted(most_influential, key=most_influential.get, reverse=True):
    print(w, most_influential[w])
# Out:
# 0 0.4557823129251701
# Twitter Web App 0.30272108843537415
# 1 0.24829931972789115
# Twitter for iPhone 0.18707482993197277
# 2 0.1326530612244898
# Twitter for Android 0.1292517006802721
# 3 0.08843537414965986
# Twitter for iPad 0.06802721088435373
# TweetDeck 0.06802721088435373
# 4 0.06462585034013606
# Twitter for Mac 0.06462585034013606
# 5 0.05442176870748299
# 6 0.05102040816326531
# Hootsuite Inc. 0.047619047619047616
# 7 0.047619047619047616
# 9 0.04081632653061224
# Buffer 0.03741496598639456
# 8 0.03741496598639456
# Twitter Media Studio 0.03741496598639456
# Echobox 0.030612244897959183
# Sprout Social 0.030612244897959183
# 12 0.030612244897959183
# 10 0.030612244897959183
# Sprinklr 0.027210884353741496
# 13 0.027210884353741496
# 11 0.027210884353741496
# The Social Jukebox 0.023809523809523808
# Facelift-Cloud 0.023809523809523808
# dlvr.it 0.02040816326530612
# Emplifi 0.02040816326530612
# 14 0.02040816326530612
# Publer.io 0.02040816326530612
# ...

# %% [markdown]
# # MOST IMPORTANT CONNECTION
#
# - nx.eigenvector_centrality

# %%
nx.eigenvector_centrality(us_graph)
# Out:
# {'smcapplication': 0.07920052702284482,
#  0: 0.41147423953638584,
#  'Twitter Web App': 0.2669144959263034,
#  2: 0.19806550521068042,
#  'Agorapulse app': 0.026871863391255163,
#  'Twitter for iPhone': 0.20461420328546567,
#  1: 0.2911991479683546,
#  'Twitter for Android': 0.19737014870790429,
#  'Paper.li': 0.0458890046166017,
#  'Hootsuite Inc.': 0.13307190389995266,
#  'LaterMedia': 0.06021919364139622,
#  'Buffer': 0.11911681351630127,
#  'WordPress.com': 0.04807427329758273,
#  'Sprinklr': 0.09678897763324412,
#  'Echobox': 0.1025538742931101,
#  'Sprout Social': 0.09372681875118913,
#  3: 0.1734480100565552,
#  'Twitter for iPad': 0.1485059556373192,
#  'TweetDeck': 0.15607827798188498,
#  'The Social Jukebox': 0.09352117391620711,
#  4: 0.1385677228790092,
#  'Twitter for Mac': 0.1077587315267558,
#  98: 0.020400875613164546,
#  5: 0.11976462500042634,
#  'HubSpot': 0.06472190064342576,
#  8: 0.09031239616801878,
#  'Instagram': 0.026871863391255163,
# ...

# %% [markdown]
# # SHORTEST CONNECTION BETWEEN
#
# - Closeness central nx.shortest_path

# %%
nx.shortest_path(us_graph,"Sprinklr", "TweetDeck")
# Out:
# ['Sprinklr', 0, 'TweetDeck']

# %%
nx.shortest_path(us_graph,"Twitter for Android", "Twitter Web App")
# Out:
# ['Twitter for Android', 0, 'Twitter Web App']

# %% [markdown]
# # BETWEENER CENTRALITY
#
# - Bridge/Connect

# %%
plt.figure(figsize=(20,20))
nx.draw_networkx(us_graph, node_color='#FF8C00', edge_color='#1E90FF')
plt.show()

# %%
nx.betweenness_centrality(us_graph)
# Out:
# {'smcapplication': 0.0022032459277846915,
#  0: 0.5296753555173592,
#  'Twitter Web App': 0.34699007503719065,
#  2: 0.07252322870764552,
#  'Agorapulse app': 0.0,
#  'Twitter for iPhone': 0.19416785237849382,
#  1: 0.19272776349638032,
#  'Twitter for Android': 0.06565896416249203,
#  'Paper.li': 0.0007709452149165278,
#  'Hootsuite Inc.': 0.009711506643060279,
#  'LaterMedia': 0.0033701688623775225,
#  'Buffer': 0.006479451785458474,
#  'WordPress.com': 0.0018341673427134354,
#  'Sprinklr': 0.0038554538618132844,
#  'Echobox': 0.005381341557166403,
#  'Sprout Social': 0.008452385276318926,
#  3: 0.020700808838229997,
#  'Twitter for iPad': 0.0217951332260501,
#  'TweetDeck': 0.016089365486520676,
#  'The Social Jukebox': 0.003964983836732876,
#  4: 0.0186545593847403,
#  'Twitter for Mac': 0.054651023932958474,
#  98: 0.0004907919017197253,
#  5: 0.016035744385753028,
#  'HubSpot': 0.002140112438708167,
#  8: 0.00878903892404152,
#  'Instagram': 0.0,
# ...

# %%
best_connector = nx.betweenness_centrality(us_graph)

for w in sorted(best_connector, key=best_connector.get, reverse=True):
    print(w, best_connector[w])
# Out:
# 0 0.5296753555173592
# Twitter Web App 0.34699007503719065
# Twitter for iPhone 0.19416785237849382
# 1 0.19272776349638032
# 2 0.07252322870764552
# Twitter for Android 0.06565896416249203
# Twitter for Mac 0.054651023932958474
# Twitter for iPad 0.0217951332260501
# 3 0.020700808838229997
# 7 0.019678864693943796
# 4 0.0186545593847403
# TweetDeck 0.016089365486520676
# 5 0.016035744385753028
# Facelift-Cloud 0.013794307951434681
# 6 0.012642794989861936
# Hootsuite Inc. 0.009711506643060279
# 8 0.00878903892404152
# Sprout Social 0.008452385276318926
# 9 0.008371726483354085
# 25 0.008204960830570283
# 10 0.00716282085232144
# Twitter Media Studio 0.0066584232585087805
# Buffer 0.006479451785458474
# 13 0.0060026544654668956
# Echobox 0.005381341557166403
# The Social Jukebox 0.003964983836732876
# Sprinklr 0.0038554538618132844
# 14 0.0036290468672561136
# 57 0.003443640284538882
# LaterMedia 0.0033701688623775225
# 18 0.0032134045221973158
# 12 0.0030675591109326785
# ...

# %% [markdown]
# # BUILDING A SUBGROUP
#
# - Retrieve all the nodes connected to a given node within a NetworkX graph
#   - Method 1: Breadth-first search
#   - Method 2: nx.node_connected_component(G,n)

# %%
group1 = nx.bfs_tree(us_graph,"TweetDeck")

# %%
nx.draw_networkx(group1, node_color='#FF8C00', edge_color='#1E90FF')

# %%
nx.node_connected_component(us_graph,"TweetDeck")
# Out:
# {0,
#  1,
#  10,
#  100,
#  102,
#  104,
#  106,
#  11,
#  112,
#  115,
#  116,
#  12,
#  1266,
#  13,
#  130,
#  135,
#  137,
#  14,
#  147,
#  15,
#  151,
#  152,
#  16,
#  162,
#  169,
#  17,
#  171,
#  173,
#  18,
#  183,
#  189,
#  19,
#  2,
#  20,
#  203,
#  205,
#  21,
#  2182,
#  22,
#  23,
#  230,
#  236,
#  24,
#  246,
#  249,
#  25,
#  26,
#  261,
#  27,
#  270,
#  278,
#  28,
#  282,
#  29,
#  290,
#  292,
#  293,
#  2976,
#  3,
#  30,
#  302,
#  305,
#  308,
#  31,
#  312,
#  32,
#  33,
#  34,
#  35,
#  356,
#  36,
#  369,
#  37,
#  378,
#  38,
#  39,
#  395,
#  4,
#  40,
#  41,
#  411,
#  42,
#  43,
#  44,
#  45,
#  454,
#  46,
#  47,
#  48,
#  49,
#  5,
#  50,
#  500,
#  51,
#  52,
#  53,
#  55,
#  56,
#  560,
#  567,
#  57,
#  58,
#  588,
#  6,
#  60,
#  61,
#  62,
#  63,
#  64,
#  65,
#  69,
#  7,
#  70,
#  72,
#  73,
#  74,
#  76,
#  78,
#  8,
#  9,
#  90,
#  92,
#  95,
#  96,
#  97,
#  98,
#  '@healthpolicyw',
#  'AIT News',
#  'ANews Twitter',
# ...

# %% [markdown]
# # ASSOCIATION
#
# nx.clustering

# %%
nx.clustering(us_graph)
# Out:
# {'smcapplication': 0,
#  0: 0,
#  'Twitter Web App': 0,
#  2: 0,
#  'Agorapulse app': 0,
#  'Twitter for iPhone': 0,
#  1: 0,
#  'Twitter for Android': 0,
#  'Paper.li': 0,
#  'Hootsuite Inc.': 0,
#  'LaterMedia': 0,
#  'Buffer': 0,
#  'WordPress.com': 0,
#  'Sprinklr': 0,
#  'Echobox': 0,
#  'Sprout Social': 0,
#  3: 0,
#  'Twitter for iPad': 0,
#  'TweetDeck': 0,
#  'The Social Jukebox': 0,
#  4: 0,
#  'Twitter for Mac': 0,
#  98: 0,
#  5: 0,
#  'HubSpot': 0,
#  8: 0,
#  'Instagram': 0,
#  'HeyOrca': 0,
#  12: 0,
#  'Salesforce - Social Studio': 0,
#  6: 0,
#  13: 0,
#  72: 0,
#  'Twitter for Advertisers.': 0,
#  18: 0,
#  'Intelligent Transport': 0,
#  27: 0,
#  7: 0,
#  9: 0,
#  19: 0,
#  'News Medical': 0,
#  567: 0,
#  16: 0,
#  'IFTTT': 0,
#  'dlvr.it': 0,
#  'Tweetbot for iΟS': 0,
#  51: 0,
#  23: 0,
#  'AIT News': 0,
#  'Science X Status Updates': 0,
#  17: 0,
#  'La Vie Zine': 0,
#  'LinkedIn': 0,
#  'nertiqatja': 0,
#  'Twitter Media Studio - LiveCut': 0,
# ...
